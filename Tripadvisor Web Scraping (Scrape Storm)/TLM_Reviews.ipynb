# %% [markdown]
# # Preview

# %%
import pandas as pd

# %%
demo = pd.read_excel('TheLeelaMumbai_Agoda.xlsx')
demo
# Out:
#                                        Title  Rating out of 10 Rating Group  \
# 0    Nice hotel with very expensive food...”               9.2  Exceptional
# 1                   Leela is always not bad”               8.0    Excellent
# 2                                       GR8”               9.6  Exceptional
# 3              Great Hotel near the Airport”               9.6  Exceptional
# 4           Good Airport/Andheri area hotel”               8.0    Excellent
# ..                                       ...               ...          ...
# 295                   Truly resort hotel!!!”              10.0  Exceptional
# 296                                    Good”               8.4    Excellent
# 297                             Exceptional”              10.0  Exceptional
# 298                             Exceptional”              10.0  Exceptional
# 299                             Exceptional”              10.0  Exceptional
#
# ...

# %%
print('Total no. of rows:',demo.shape[0])
# Out:
# Total no. of rows: 300
